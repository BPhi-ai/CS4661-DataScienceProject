# %% [markdown]
# ### Plot the training.csv and test.csv
# Read the df head

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('training.csv')
df.head(8029)
# Out:
#       correct  outcome  user_id  question_id  question_type  group_name  \
# 0           0        2    85818         5560              0           1
# 1           1        1    85818         4681              0           1
# 2           1        1    85818         1529              0           1
# 3           1        1    85818         2908              0           1
# 4           1        1    85818         1773              0           1
# ...       ...      ...      ...          ...            ...         ...
# 8024        0        4   170305         2862              0           1
# 8025        0        4   170305         1529              0           1
# 8026        0        4    26520         5813              0           0
# 8027        1        1    15138         1272              0           2
# 8028        0        2    15138         4444              0           2
#
#       track_name  subtrack_name           tag_string     round_started_at  \
# 0              5             14      222 233 240 246  2010-08-18 20:17:13
# 1              5              0                24 49  2010-08-18 20:19:12
# 2              5              0                31 49  2010-08-18 20:20:42
# 3              5              0                31 49  2010-08-18 20:22:03
# 4              5             11          183 194 207  2010-08-18 20:23:11
# ...          ...            ...                  ...                  ...
# 8024           4              9         14 68 77 161  2010-11-07 22:14:41
# 8025           5              0                31 49  2010-11-07 22:19:48
# 8026           0              2  38 57 63 65 140 141  2011-04-18 12:27:14
# 8027           7             13              239 245  2010-05-04 18:23:44
# 8028           7             13          223 239 245  2010-05-04 18:27:44
#
#               answered_at       deactivated_at  answer_id  game_type  \
# 0     2010-08-18 20:18:18  2010-08-18 20:18:18     6540.0        7.0
# 1     2010-08-18 20:20:34  2010-08-18 20:20:34     4742.0        7.0
# 2     2010-08-18 20:21:56  2010-08-18 20:21:56     4309.0        7.0
# 3     2010-08-18 20:23:05  2010-08-18 20:23:05     4408.0        7.0
# 4     2010-08-18 20:26:08  2010-08-18 20:26:08    10822.0        7.0
# ...                   ...                  ...        ...        ...
# 8024                  NaN  2010-11-07 22:17:11    25553.0        7.0
# 8025                  NaN  2010-11-07 22:20:51    25553.0        7.0
# 8026                  NaN  2011-04-18 12:28:24    25553.0        5.0
# 8027  2010-05-04 18:27:32  2010-05-04 18:27:32    19946.0        7.0
# 8028  2010-05-04 18:30:05  2010-05-04 18:30:05    19949.0        7.0
#
#       num_players date_of_test  question_set_id
# 0             1.0          NaN           1567.0
# 1             1.0          NaN           1227.0
# 2             1.0          NaN           1148.0
# 3             1.0          NaN           1168.0
# 4             1.0          NaN           2318.0
# ...           ...          ...              ...
# 8024          1.0          NaN           1837.0
# 8025          1.0          NaN           1148.0
# 8026          1.0          NaN           2324.0
# 8027          1.0          NaN           3676.0
# 8028          1.0          NaN           3677.0
#
# [8029 rows x 17 columns]

# %%
grouped = df.groupby(['user_id', 'question_type', 'track_name'])
mean_values = grouped.mean()

# %%
mean_values.plot(kind='bar')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Graph title')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, ncol=3)
plt.show()
