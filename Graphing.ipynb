# %% [markdown]
# ### Plot the training.csv and test.csv
# Read the df head

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('training.csv')
df.head(8029)
# Out:
#        correct  outcome  question_id  question_type  group_name  track_name  \
# 0            0        2         5560              0           1           5
# 1            1        1         4681              0           1           5
# 2            1        1         1529              0           1           5
# 3            1        1         2908              0           1           5
# 4            1        1         1773              0           1           5
# ...        ...      ...          ...            ...         ...         ...
# 10996        0        2         4717              0           2           6
# 10997        0        2         4099              0           2           6
# 10998        0        2         2320              0           2           6
# 10999        0        2         2013              0           2           6
# 11000        1        1          234              0           2           6
#
#        subtrack_name          tag_string     round_started_at  \
# 0                 14     222 233 240 246  2010-08-18 20:17:13
# 1                  0               24 49  2010-08-18 20:19:12
# 2                  0               31 49  2010-08-18 20:20:42
# 3                  0               31 49  2010-08-18 20:22:03
# 4                 11         183 194 207  2010-08-18 20:23:11
# ...              ...                 ...                  ...
# 10996              7        5 87 131 264  2011-04-01 22:19:22
# 10997              7      83 119 131 169  2011-04-01 22:19:26
# 10998              7   66 83 131 150 169  2011-04-01 22:19:32
# 10999              7  15 121 131 137 279  2011-04-01 22:19:39
# 11000              7      53 131 138 159  2011-04-01 22:19:42
#
#                answered_at       deactivated_at  answer_id  game_type  \
# 0      2010-08-18 20:18:18  2010-08-18 20:18:18     6540.0        7.0
# 1      2010-08-18 20:20:34  2010-08-18 20:20:34     4742.0        7.0
# 2      2010-08-18 20:21:56  2010-08-18 20:21:56     4309.0        7.0
# 3      2010-08-18 20:23:05  2010-08-18 20:23:05     4408.0        7.0
# 4      2010-08-18 20:26:08  2010-08-18 20:26:08    10822.0        7.0
# ...                    ...                  ...        ...        ...
# 10996  2011-04-01 22:19:24  2011-04-01 22:19:26     2609.0        7.0
# 10997  2011-04-01 22:19:31  2011-04-01 22:19:31     3475.0        7.0
# 10998  2011-04-01 22:19:36  2011-04-01 22:19:38     3561.0        7.0
# 10999  2011-04-01 22:19:40  2011-04-01 22:19:42     3796.0        7.0
# 11000  2011-04-01 22:19:44               2011-0        NaN        NaN
#
#        num_players date_of_test  question_set_id
# 0              1.0          NaN           1567.0
# 1              1.0          NaN           1227.0
# 2              1.0          NaN           1148.0
# 3              1.0          NaN           1168.0
# 4              1.0          NaN           2318.0
# ...            ...          ...              ...
# 10996          1.0          NaN            816.0
# 10997          1.0          NaN            993.0
# 10998          1.0          NaN           1009.0
# 10999          1.0          NaN           1050.0
# 11000          NaN          NaN              NaN
#
# [11001 rows x 16 columns]

# %%
grouped = df.groupby(['question_type', 'game_type'])
mean_values = grouped.mean()
mean_values = mean_values.groupby('user_id')

# %%
mean_values.plot(kind='bar')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Graph title')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, ncol=3)
plt.show()
