# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/JayDevelops/dataScienceTeamProject/main/benchmark_lmer_submission.csv?token=GHSAT0AAAAAAB3VVDKOZFVFIZVSHQN6S3LMY4SHHOQ');
scores = df.head(82926)
scores
# Out:
#        user_id   outcome
# 0            0  0.458734
# 1            1  0.801818
# 2            2  0.482292
# 3            4  0.339889
# 4            5  0.508015
# ...        ...       ...
# 82921   159512  0.736745
# 82922   159514  0.879915
# 82923   159516  0.228173
# 82924   159518  0.457979
# 82925   159521  0.590863
#
# [82926 rows x 2 columns]

# %%
AGrade = scores.loc[(df['outcome'] < 1) & (df['outcome'] >= 0.9)];
AGrade
# Out:
#        user_id   outcome
# 16          28  0.959635
# 33          55  0.963655
# 54         100  0.928077
# 83         171  0.915251
# 89         180  0.901407
# ...        ...       ...
# 82687   159093  0.914308
# 82745   159198  0.932105
# 82767   159242  0.920397
# 82807   159314  0.951836
# 82875   159430  0.912119
#
# [3459 rows x 2 columns]

# %%
BGrade = scores.loc[(df['outcome'] < 0.9) & (df['outcome'] >= 0.8)];
BGrade
# Out:
#        user_id   outcome
# 1            1  0.801818
# 13          20  0.874204
# 20          34  0.892025
# 23          40  0.848913
# 31          53  0.839239
# ...        ...       ...
# 82892   159457  0.851896
# 82909   159492  0.823891
# 82913   159504  0.888863
# 82914   159505  0.824195
# 82922   159514  0.879915
#
# [9006 rows x 2 columns]

# %%
CGrade = scores.loc[(df['outcome'] < 0.8) & (df['outcome'] >= 0.7)];
CGrade
# Out:
#        user_id   outcome
# 9           13  0.755086
# 12          19  0.703792
# 14          22  0.796361
# 18          31  0.798014
# 19          32  0.724611
# ...        ...       ...
# 82883   159446  0.762745
# 82901   159479  0.777235
# 82905   159488  0.713086
# 82920   159511  0.737710
# 82921   159512  0.736745
#
# [10790 rows x 2 columns]

# %%
DGrade = scores.loc[(df['outcome'] < 0.7) & (df['outcome'] >= 0.6)];
DGrade
# Out:
#        user_id   outcome
# 7           10  0.680912
# 22          37  0.677789
# 45          77  0.641993
# 56         103  0.609584
# 57         107  0.690603
# ...        ...       ...
# 82863   159413  0.654938
# 82897   159465  0.648505
# 82906   159489  0.653283
# 82916   159507  0.638451
# 82918   159509  0.658228
#
# [11314 rows x 2 columns]

# %%
FGrade = scores.loc[(df['outcome'] < 0.6) & (df['outcome'] >= 0)];
FGrade
# Out:
#        user_id   outcome
# 0            0  0.458734
# 2            2  0.482292
# 3            4  0.339889
# 4            5  0.508015
# 5            6  0.514928
# ...        ...       ...
# 82917   159508  0.115448
# 82919   159510  0.547028
# 82923   159516  0.228173
# 82924   159518  0.457979
# 82925   159521  0.590863
#
# [48357 rows x 2 columns]

# %%
average = pd.DataFrame({'GradeValue': ['A Grade', 'B Grade', 'C Grade', 'D Grade', 'F Grade'], 'Applicants': [3459, 9006, 10790, 11314, 48357]})
average.groupby(['GradeValue']).sum().plot(kind='pie', y='Applicants');
