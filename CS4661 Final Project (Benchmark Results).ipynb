# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/JayDevelops/dataScienceTeamProject/main/benchmark_lmer_submission.csv?token=GHSAT0AAAAAAB3VVDKOZFVFIZVSHQN6S3LMY4SHHOQ');
scores = df.head(82926)
scores
# Out:
#        user_id   outcome
# 0            0  0.458734
# 1            1  0.801818
# 2            2  0.482292
# 3            4  0.339889
# 4            5  0.508015
# ...        ...       ...
# 82921   159512  0.736745
# 82922   159514  0.879915
# 82923   159516  0.228173
# 82924   159518  0.457979
# 82925   159521  0.590863
#
# [82926 rows x 2 columns]

# %%
AGrade = df.loc[(df['outcome'] < 1) & (df['outcome'] >= 0.9)];
AGrade
# Out:
#        user_id   outcome
# 16          28  0.959635
# 33          55  0.963655
# 54         100  0.928077
# 83         171  0.915251
# 89         180  0.901407
# ...        ...       ...
# 93008   178935  0.905163
# 93009   178936  0.961748
# 93033   178980  0.912457
# 93041   178995  0.915251
# 93074   179056  0.907627
#
# [3899 rows x 2 columns]

# %%
BGrade = df.loc[(df['outcome'] < 0.9) & (df['outcome'] >= 0.8)];
BGrade
# Out:
#        user_id   outcome
# 1            1  0.801818
# 13          20  0.874204
# 20          34  0.892025
# 23          40  0.848913
# 31          53  0.839239
# ...        ...       ...
# 93080   179066  0.868292
# 93084   179080  0.868004
# 93092   179093  0.818711
# 93094   179095  0.858171
# 93098   179101  0.815370
#
# [10098 rows x 2 columns]

# %%
CGrade = df.loc[(df['outcome'] < 0.8) & (df['outcome'] >= 0.7)];
CGrade
# Out:
#        user_id   outcome
# 9           13  0.755086
# 12          19  0.703792
# 14          22  0.796361
# 18          31  0.798014
# 19          32  0.724611
# ...        ...       ...
# 93069   179047  0.785026
# 93082   179070  0.745945
# 93085   179082  0.721795
# 93089   179087  0.729070
# 93090   179089  0.709912
#
# [12047 rows x 2 columns]

# %%
DGrade = df.loc[(df['outcome'] < 0.7) & (df['outcome'] >= 0.6)];
DGrade
# Out:
#        user_id   outcome
# 7           10  0.680912
# 22          37  0.677789
# 45          77  0.641993
# 56         103  0.609584
# 57         107  0.690603
# ...        ...       ...
# 93052   179014  0.617480
# 93063   179036  0.682616
# 93066   179041  0.631345
# 93088   179086  0.646622
# 93096   179097  0.684421
#
# [12661 rows x 2 columns]

# %%
FGrade = df.loc[(df['outcome'] < 0.6) & (df['outcome'] >= 0)];
FGrade
# Out:
#        user_id   outcome
# 0            0  0.458734
# 2            2  0.482292
# 3            4  0.339889
# 4            5  0.508015
# 5            6  0.514928
# ...        ...       ...
# 93091   179092  0.247288
# 93093   179094  0.082748
# 93095   179096  0.231220
# 93097   179098  0.409533
# 93099   179104  0.480943
#
# [54395 rows x 2 columns]

# %%
average = pd.DataFrame({'GradeValue': ['AGrade', 'BGrade', 'CGrade', 'DGrade', 'FGrade'], 'Applicants': [3899, 10098, 12047, 12661, 54395]})
average.groupby(['GradeValue']).sum().plot(kind='pie', y='Applicants');
