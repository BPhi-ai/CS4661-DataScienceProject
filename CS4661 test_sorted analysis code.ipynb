# %%
import pandas as pd


df = pd.read_csv('test_sorted.csv')
df = df.loc[:, ~df.columns.isin(['round_started_at', 'date_of_test'])];
df
# Out:
#        user_id  question_id             question_type group_name  \
# 0            0         2928  MultipleChoiceOneCorrect        act
# 1            1         1668  MultipleChoiceOneCorrect       gmat
# 2            2         4629  MultipleChoiceOneCorrect        act
# 3            4         2488  MultipleChoiceOneCorrect       gmat
# 4            5         4505  MultipleChoiceOneCorrect        sat
# ...        ...          ...                       ...        ...
# 82921   181697         1609  MultipleChoiceOneCorrect        sat
# 82922   181698         2315  MultipleChoiceOneCorrect        sat
# 82923   181699         1483  MultipleChoiceOneCorrect       gmat
# 82924   181701         1329  MultipleChoiceOneCorrect       gmat
# 82925   181702         1917  MultipleChoiceOneCorrect        sat
#
#               track_name        subtrack_name  \
# 0            ACT Reading              Reading
# 1      GMAT Quantitative      Problem Solving
# ...

# %%
sat = df.loc[df['group_name'] == 'sat']
sat
# Out:
#        user_id  question_id             question_type group_name   track_name  \
# 4            5         4505  MultipleChoiceOneCorrect        sat  SAT Writing
# 7           10         1466  MultipleChoiceOneCorrect        sat     SAT Math
# 9           13         4809  MultipleChoiceOneCorrect        sat     SAT Math
# 22          41         5327  MultipleChoiceOneCorrect        sat     SAT Math
# 25          45         5706  MultipleChoiceOneCorrect        sat     SAT Math
# ...        ...          ...                       ...        ...          ...
# 82906   181671         1858  MultipleChoiceOneCorrect        sat     SAT Math
# 82916   181690         4444  MultipleChoiceOneCorrect        sat  SAT Reading
# 82921   181697         1609  MultipleChoiceOneCorrect        sat  SAT Writing
# 82922   181698         2315  MultipleChoiceOneCorrect        sat  SAT Writing
# 82925   181702         1917  MultipleChoiceOneCorrect        sat  SAT Reading
#
# ...

# %%
act = df.loc[df['group_name'] == 'act']
act
# Out:
#        user_id  question_id             question_type group_name   track_name  \
# 0            0         2928  MultipleChoiceOneCorrect        act  ACT Reading
# 2            2         4629  MultipleChoiceOneCorrect        act  ACT Reading
# 5            6          186  MultipleChoiceOneCorrect        act  ACT Science
# 6            9         1406  MultipleChoiceOneCorrect        act  ACT English
# 18          32          857  MultipleChoiceOneCorrect        act     ACT Math
# ...        ...          ...                       ...        ...          ...
# 82909   181674         2844  MultipleChoiceOneCorrect        act  ACT English
# 82911   181680         3617  MultipleChoiceOneCorrect        act     ACT Math
# 82915   181689         4948  MultipleChoiceOneCorrect        act  ACT English
# 82917   181691         3541  MultipleChoiceOneCorrect        act     ACT Math
# 82919   181693         3546  MultipleChoiceOneCorrect        act  ACT Science
#
# ...

# %%
gmat = df.loc[df['group_name'] == 'gmat']
gmat
# Out:
#        user_id  question_id             question_type group_name  \
# 1            1         1668  MultipleChoiceOneCorrect       gmat
# 3            4         2488  MultipleChoiceOneCorrect       gmat
# 8           12          851  MultipleChoiceOneCorrect       gmat
# 10          14         4531  MultipleChoiceOneCorrect       gmat
# 11          16         4245  MultipleChoiceOneCorrect       gmat
# ...        ...          ...                       ...        ...
# 82914   181687         4923  MultipleChoiceOneCorrect       gmat
# 82918   181692         4179  MultipleChoiceOneCorrect       gmat
# 82920   181695         3707  MultipleChoiceOneCorrect       gmat
# 82923   181699         1483  MultipleChoiceOneCorrect       gmat
# 82924   181701         1329  MultipleChoiceOneCorrect       gmat
#
#               track_name        subtrack_name  \
# 1      GMAT Quantitative      Problem Solving
# 3            GMAT Verbal   Critical Reasoning
# ...

# %%
question = df.loc[df['question_id'] == 6050]
question
# Out:
# Empty DataFrame
# Columns: [user_id, question_id, question_type, group_name, track_name, subtrack_name, tag_string, game_type, num_players, question_set_id]
# Index: []

# %%
maximum = df['question_id'].unique()
len(maximum)
# Out:
# 5477

# %%
outcome = pd.read_csv('training.csv')
outcome
# Out:
#          correct  outcome  user_id  question_id  question_type  group_name  \
# 0              0        2    85818         5560              0           1
# 1              1        1    85818         4681              0           1
# 2              1        1    85818         1529              0           1
# 3              1        1    85818         2908              0           1
# 4              1        1    85818         1773              0           1
# ...          ...      ...      ...          ...            ...         ...
# 4851470        1        1    58569         1633              0           1
# 4851471        0        4    58569         1775              0           1
# 4851472        0        4   131842         1655              0           2
# 4851473        0        4   131842          544              0           2
# 4851474        0        4    52513         1272              0           2
#
# ...

# %%
#0 = no value, #1 = correct, #2 = incorrect #3 = timed-out #4 = skipped.
df['correct?'] = outcome['correct']
df['status of question'] = outcome['outcome']
df
# Out:
#        user_id  question_id             question_type group_name  \
# 0            0         2928  MultipleChoiceOneCorrect        act
# 1            1         1668  MultipleChoiceOneCorrect       gmat
# 2            2         4629  MultipleChoiceOneCorrect        act
# 3            4         2488  MultipleChoiceOneCorrect       gmat
# 4            5         4505  MultipleChoiceOneCorrect        sat
# ...        ...          ...                       ...        ...
# 82921   181697         1609  MultipleChoiceOneCorrect        sat
# 82922   181698         2315  MultipleChoiceOneCorrect        sat
# 82923   181699         1483  MultipleChoiceOneCorrect       gmat
# 82924   181701         1329  MultipleChoiceOneCorrect       gmat
# 82925   181702         1917  MultipleChoiceOneCorrect        sat
#
#               track_name        subtrack_name  \
# 0            ACT Reading              Reading
# 1      GMAT Quantitative      Problem Solving
# ...

# %%
#for every question, how many users have encountered that question.
usersPerQuestion = []
usersPerQuestionWithoutZero = []
questionIDWithoutZeroUsers = []

for n in range(5477):
    x = df.loc[df['question_id'] == n]
    if(len(x) != 0):
        usersPerQuestion.append(len(x))
        questionIDWithoutZeroUsers.append(df['question_id'].loc[df.index[n]])
        print('question id: ' + str(df['question_id'].loc[df.index[n]]) + " users: " + str(len(x)))

for x in usersPerQuestion:
    if (x != 0):
        usersPerQuestionWithoutZero.append(x)

for y in usersPerQuestionWithoutZero:
    print("users: " + str(y))
    
#list of question_id that has at least 1 user.
noduplicate = list(set(questionIDWithoutZeroUsers))
# Out:
# question id: 2928 users: 13
# question id: 1668 users: 3
# question id: 4629 users: 24
# question id: 2488 users: 9
# question id: 4505 users: 4
# question id: 186 users: 22
# question id: 1406 users: 15
# question id: 1466 users: 23
# question id: 4809 users: 15
# question id: 4531 users: 3
# question id: 4245 users: 4
# question id: 3442 users: 35
# question id: 3041 users: 5
# question id: 4133 users: 11
# question id: 1453 users: 2
# question id: 45 users: 17
# question id: 180 users: 14
# question id: 857 users: 10
# question id: 5082 users: 7
# question id: 5539 users: 16
# question id: 5591 users: 16
# question id: 5327 users: 3
# question id: 2223 users: 4
# question id: 733 users: 2
# question id: 5706 users: 21
# question id: 5623 users: 2
# question id: 1843 users: 1
# question id: 2608 users: 16
# question id: 4103 users: 3
# question id: 4299 users: 2
# question id: 3203 users: 57
# question id: 4719 users: 38
# question id: 4346 users: 6
# question id: 779 users: 7
# ...

# %%
for a in noduplicate:
    print("question_id: " + str(a))
# Out:
# question_id: 0
# question_id: 2
# question_id: 5
# question_id: 6
# question_id: 9
# question_id: 12
# question_id: 17
# question_id: 18
# question_id: 20
# question_id: 23
# question_id: 25
# question_id: 28
# question_id: 29
# question_id: 30
# question_id: 31
# question_id: 32
# question_id: 35
# question_id: 38
# question_id: 42
# question_id: 45
# question_id: 48
# question_id: 55
# question_id: 57
# question_id: 59
# question_id: 62
# question_id: 64
# question_id: 66
# question_id: 67
# question_id: 68
# question_id: 72
# question_id: 75
# question_id: 80
# question_id: 81
# question_id: 82
# question_id: 84
# question_id: 88
# question_id: 89
# question_id: 91
# question_id: 93
# question_id: 94
# question_id: 95
# question_id: 97
# question_id: 99
# question_id: 100
# question_id: 101
# question_id: 103
# question_id: 105
# question_id: 107
# question_id: 109
# question_id: 111
# question_id: 112
# question_id: 117
# question_id: 121
# question_id: 126
# question_id: 127
# ...

# %%
#correctQuestion = df.loc[(df['question_id'] == 2928) & (df['correct?'] == 1)]
#correctQuestion
correctUsersPerQuestion = []

for n in questionIDWithoutZeroUsers:
        correctQ = df.loc[(df['question_id'] == n) & (df['correct?'] == 1)]
        correctUsersPerQuestion.append(len(correctQ))
        print('question_id: ' + str(n) + " correct users: " + str(len(correctQ.index)))
# Out:
# question_id: 2928 correct users: 33
# question_id: 1668 correct users: 39
# question_id: 4629 correct users: 20
# question_id: 2488 correct users: 15
# question_id: 4505 correct users: 88
# question_id: 186 correct users: 38
# question_id: 1406 correct users: 17
# question_id: 1466 correct users: 16
# question_id: 4809 correct users: 45
# question_id: 4531 correct users: 7
# question_id: 4245 correct users: 5
# question_id: 3442 correct users: 20
# question_id: 3041 correct users: 11
# question_id: 4133 correct users: 7
# question_id: 1453 correct users: 142
# question_id: 45 correct users: 19
# question_id: 180 correct users: 19
# question_id: 857 correct users: 22
# question_id: 5082 correct users: 179
# question_id: 5539 correct users: 33
# question_id: 5591 correct users: 71
# question_id: 5327 correct users: 176
# question_id: 2223 correct users: 32
# question_id: 733 correct users: 16
# question_id: 5706 correct users: 222
# question_id: 5623 correct users: 18
# ...

# %%
correctQ = df.loc[(df['question_id'] == 0) & (df['correct?'] == 1)]
correctQ
# Out:
#        user_id  question_id             question_type group_name   track_name  \
# 25362    55623            0  MultipleChoiceOneCorrect        sat  SAT Reading
# 33844    74420            0  MultipleChoiceOneCorrect        sat  SAT Reading
# 42255    92895            0  MultipleChoiceOneCorrect        sat  SAT Reading
# 50223   110269            0  MultipleChoiceOneCorrect        sat  SAT Reading
# 60127   132401            0  MultipleChoiceOneCorrect        sat  SAT Reading
# 80018   176476            0  MultipleChoiceOneCorrect        sat  SAT Reading
#
#              subtrack_name                          tag_string  \
# 25362  Sentence Completion  SC: Two Blanks|Sentence Completion
# 33844  Sentence Completion  SC: Two Blanks|Sentence Completion
# 42255  Sentence Completion  SC: Two Blanks|Sentence Completion
# 50223  Sentence Completion  SC: Two Blanks|Sentence Completion
# 60127  Sentence Completion  SC: Two Blanks|Sentence Completion
# ...

# %%
#do tables noduplicate and usersperquestionwithoutzeros for making a new dataframe.
